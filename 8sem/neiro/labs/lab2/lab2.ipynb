# %% [markdown]
# **Лабораторная работа 2**
#
# **Нейрон Мак-Каллока — Питтса. Перцептрон. Логические нейронно-сетевые операции.**

# %%
import numpy as np

# %% [markdown]
# *В ноутбуке находится функция McCulloch_Pitts_OR, реализующая вычисление логической функции «ИЛИ» с использованием нейрона Мак-Каллока-Питтса. Изучите код программы и продемонстрируйте ее правильную работу.*

# %%
def McCulloch_Pitts_OR():
    print('Введите веса')
    w1 = float(input('Вес w1 = '))
    w2 = float(input('Вес w2 = '))
    print('Введите величину порога')
    theta = float(input('Порог = '))

    y = [0, 0, 0, 0]
    x1 = [1, 1, 0, 0]
    x2 = [1, 0, 1, 0]
    z = [1, 1, 1, 0]
    con = 1

    while con:
        zin = [x1[i] * w1 + x2[i] * w2 for i in range(4)]

        for i in range(4):
            if zin[i] >= theta:
                y[i] = 1
            else:
                y[i] = 0

        print('Значение на выходе нейрона')
        print(y)

        if y == z:
            con = 0
        else:
            print('Нейрон не обучен. Введите другие значения весовых коэффициентов и порога')
            w1 = float(input('Вес w1 = '))
            w2 = float(input('Вес w2 = '))
            theta = float(input('Порог = '))

    print('Нейрон МакКаллока-Питса для функции "ИЛИ" (англ. "OR")')
    print('Веса нейрона')
    print(w1)
    print(w2)
    print('Пороговое значение')
    print(theta)

# %%
McCulloch_Pitts_OR()
# Out:
# Введите веса
# Введите величину порога
# Значение на выходе нейрона
# [1, 0, 0, 0]
# Нейрон не обучен. Введите другие значения весовых коэффициентов и порога
# Значение на выходе нейрона
# [1, 1, 1, 0]
# Нейрон МакКаллока-Питса для функции "ИЛИ" (англ. "OR")
# Веса нейрона
# 1.0
# 1.0
# Пороговое значение
# 0.5

# %% [markdown]
# *Используя функцию McCulloch_Pitts_OR, напишите функцию McCulloch_Pitts_AND, реализующую вычисление логической функции «И» с использованием нейрона Мак-КаллокаПиттса.*

# %%
def McCulloch_Pitts_AND():
    print('Введите веса')
    w1 = float(input('Вес w1 = '))
    w2 = float(input('Вес w2 = '))
    print('Введите величину порога')
    theta = float(input('Порог = '))

    y = [0, 0, 0, 0]
    x1 = [1, 1, 0, 0]
    x2 = [1, 0, 1, 0]
    z = [1, 0, 0, 0]
    con = 1

    while con:
        zin = [x1[i] * w1 + x2[i] * w2 for i in range(4)]

        for i in range(4):
            if zin[i] >= theta:
                y[i] = 1
            else:
                y[i] = 0

        print('Значение на выходе нейрона')
        print(y)

        if y == z:
            con = 0
        else:
            print('Нейрон не обучен. Введите другие значения весовых коэффициентов и порога')
            w1 = float(input('Вес w1 = '))
            w2 = float(input('Вес w2 = '))
            theta = float(input('Порог = '))

    print('Нейрон МакКаллока-Питса для функции "И" (англ. "AND")')
    print('Веса нейрона')
    print(w1)
    print(w2)
    print('Пороговое значение')
    print(theta)

# %%
McCulloch_Pitts_AND()
# Out:
# Введите веса
# Введите величину порога
# Значение на выходе нейрона
# [1, 0, 0, 0]
# Нейрон МакКаллока-Питса для функции "И" (англ. "AND")
# Веса нейрона
# 0.5
# 0.5
# Пороговое значение
# 1.0

# %% [markdown]
# *Используя функцию McCulloch_Pitts_AND, напишите функцию McCulloch_Pitts_AND_bipolar, реализующую вычисление логической функции «И» с использованием нейрона Мак-КаллокаПиттса с биполярными входами и выходами.*

# %%
def McCulloch_Pitts_AND_bipolar():
    print('Введите веса')
    w1 = float(input('Вес w1 = '))
    w2 = float(input('Вес w2 = '))
    print('Введите величину порога')
    theta = float(input('Порог = '))

    y = [0, 0, 0, 0]
    x1 = [1, 1, -1, -1]
    x2 = [1, -1, 1, -1]
    z = [1, -1, -1, -1]
    con = 1

    while con:
        zin = [x1[i] * w1 + x2[i] * w2 for i in range(4)]

        for i in range(4):
            if zin[i] >= theta:
                y[i] = 1
            else:
                y[i] = -1

        print('Значение на выходе нейрона')
        print(y)

        if y == z:
            con = 0
        else:
            print('Нейрон не обучен. Введите другие значения весовых коэффициентов и порога')
            w1 = float(input('Вес w1 = '))
            w2 = float(input('Вес w2 = '))
            theta = float(input('Порог = '))

    print('Нейрон МакКаллока-Питса для функции "И" с биполярными входами и выходами')
    print('Веса нейрона')
    print(w1)
    print(w2)
    print('Пороговое значение')
    print(theta)

# %%
McCulloch_Pitts_AND_bipolar()
# Out:
# Введите веса
# Введите величину порога
# Значение на выходе нейрона
# [1, -1, -1, -1]
# Нейрон МакКаллока-Питса для функции "И" с биполярными входами и выходами
# Веса нейрона
# 1.0
# 1.0
# Пороговое значение
# 0.5

# %% [markdown]
# *Используя программу ранее подготовленные коды, написать программу McCulloch_Pitts_XOR, реализующую нейросетевое вычисление логической функции «Исключающее ИЛИ» (англ. XOR).*

# %%
def McCulloch_Pitts_XOR():
    print('Введите веса')
    w11 = float(input('Вес w11 ='))
    w12 = float(input('Вес w12 ='))
    w21 = float(input('Вес w21 ='))
    w22 = float(input('Вес w22 ='))
    w31 = float(input('Вес w31 ='))
    w32 = float(input('Вес w32 ='))
    print('Введите величину порога')
    theta = float(input('Порог = '))

    x1 = [0, 1, 0, 1]
    x2 = [0, 0, 1, 1]
    hidden1 = [0, 0, 0, 0]
    hidden2 = [0, 0, 0, 0]
    y = [0, 0, 0, 0]

    print('Нейрон МакКаллока-Питса для функции бинарной функции XOR')
    print('Значения на входах и выходе сети')
    print()
    print('X1    ', end='')
    for val in x1:
        print(f'{val}     ', end='')
    print()

    print('X2    ', end='')
    for val in x2:
        print(f'{val}     ', end='')
    print()

    for i in range(4):
        zin1 = x1[i] * w11 + x2[i] * w12
        if zin1 >= theta:
            hidden1[i] = 1
        else:
            hidden1[i] = 0

        zin2 = x1[i] * w21 + x2[i] * w22
        if zin2 >= theta:
            hidden2[i] = 1
        else:
            hidden2[i] = 0

        zin_out = hidden1[i] * w31 + hidden2[i] * w32
        if zin_out >= theta:
            y[i] = 1
        else:
            y[i] = 0

    print('Y     ', end='')
    for val in y:
        print(f'{val}     ', end='')
    print()

    print('\nПараметры сети:')
    print(f'w11 = {w11}, w12 = {w12}')
    print(f'w21 = {w21}, w22 = {w22}')
    print(f'w31 = {w31}, w32 = {w32}')
    print(f'Порог theta = {theta}')

# %%
McCulloch_Pitts_XOR()
# Out:
# Введите веса
# Введите величину порога
# Нейрон МакКаллока-Питса для функции бинарной функции XOR
# Значения на входах и выходе сети
#
# X1    0     1     0     1
# X2    0     0     1     1
# Y     0     1     1     0
#
# Параметры сети:
# w11 = 1.0, w12 = -1.0
# w21 = -1.0, w22 = 1.0
# w31 = 1.0, w32 = 1.0
# Порог theta = 1.0
